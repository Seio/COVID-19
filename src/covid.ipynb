# %%
import pandas as pd
import numpy as nps
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import seaborn as sns
sns.set(style="darkgrid")

# %%
df = pd.read_csv('dati-andamento-nazionale/dpc-covid19-ita-andamento-nazionale.csv', parse_dates=['data'], index_col=['data'])

# %%
plt.scatter(df.index.strftime('%d'), df.totale_casi)
